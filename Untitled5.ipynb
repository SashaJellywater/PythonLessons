# %% [markdown]
# <a href="https://colab.research.google.com/github/SashaJellywater/PythonLessons/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')
df.head()

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
import seaborn as sns
sns.scatterplot(x = df['households'], y = df['population'])
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
plt.figure(figsize = (14,5))
sns.lineplot(x = df['longitude'], y = df['median_house_value']);
#sns.relplot(x = df['longitude'], y = df['median_house_value'],kind = 'line');

# %%
sns.histplot(x = df['housing_median_age']);

# %%
df[(df['housing_median_age']>30)&(df['housing_median_age']<35)].count()
# Out:
# longitude             1538
# latitude              1538
# housing_median_age    1538
# total_rooms           1538
# total_bedrooms        1538
# population            1538
# households            1538
# median_income         1538
# median_house_value    1538
# dtype: int64

# %%
sns.histplot(data = df, x = 'median_house_value', hue = 'housing_median_age');
